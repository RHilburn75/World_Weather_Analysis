# %%
# import dependencies
from citipy import citipy
import gmaps
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
import time
from config import g_key

from datetime import datetime
from config import weather_api_key

# %%
##Create a new set of 2,000 random latitudes and longitudes.
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#unpack lat_lngs zip objects into the list
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-63.03536873345797, -56.37823802736074), (64.15263303207664, 60.619929016610484), (-33.33084064477178, 83.94558532128991), (-2.9458995664633107, -42.989054041160614), (-8.325028844449733, 45.62743904573611), (-87.70389116159589, -74.62550710147448), (81.98278333703615, -135.34390399209292), (39.99118822431271, 102.48904682557662), (28.412104136831857, 67.09596337400257), (42.9295180174702, 73.30981608053685), (69.29738183534198, -47.75317177245691), (-70.6764099953209, 147.88303823701034), (36.45119833780501, -63.35199471027731), (5.666530727801458, 40.5548216786967), (30.533000189053396, 29.442120090456342), (-11.70551508914967, -47.91543369492973), (24.828466530495433, 134.25592040602896), (26.894211233689234, -54.44434058066339), (-22.244110261242994, -177.3026842139822), (82.06524592939371, 118.10133735823314), (-65.52014158790803, -60.72001898954001), (47.552695046149836, 151.17505306188116), (18.51578176572704, 174.07127059403604), (80.48124284018726, 70.25982637877266), (-31.28043525676965, -39.43309356821041), (39.81587764769273, 82.07738849583603), (68.5196450145196, 169.75059725652966), (24.36059333157661, -84.68140148413359), (-0.6611220332946885, -103.13309773025615), (21.939986531088323, 81.11308371586028), (-52.90579478851479, 120.03831490897028), (33.233384828656014, -45.419644909453694), (0.7805748100851275, 43.03450833472459), (-47.95986537357458, -41.86309328696086), (-52.96751359149011, 147.3806547394018), (62.26612514783881, 100.98067128553237), (-10.818077452687305, -9.460765669727408), (-27.267962355088272, 45.79532433480995), (15.45123118079509, -75.42386793408755), (-49.61266799638021, -121.820420532274), (-59.580390809788526, 135.23667979040437), (-86.6715070111382, -102.00060467477593), (26.581868524983847, -158.3277533686067), (18.627708594222682, -16.355851300448535), (62.919398330856694, -61.28617664505265), (82.33104719472882, 100.82251743411996), (-88.03914081877724, -115.47875279206472), (-88.07741087775973, -140.50630162006766), (-38.01437263053047, -99.14018117937675), (1.089694722423772, -154.23751490285656), (82.40618168534198, -147.11618982810768), (17.14162661395447, -111.07678796535714), (-44.08932974920299, 4.641415427382128), (-16.8209559074447, 109.16699508475244), (22.783024002577235, -97.5121763993643), (49.30957541753568, 101.04844921621435), (-40.66411708945612, -47.19243974874118), (-4.946643666201126, 123.4269319731763), (48.62819159064915, 59.538405283987856), (-38.98597497334045, 142.12941769137473), (-56.293598234817004, -53.680768298558604), (86.67164593710618, 122.87825301064532), (-85.89130208340087, 62.27945975949433), (-76.50444455551929, 37.95581640057375), (41.4847922145143, 67.29726292631545), (8.977520025871627, 10.209933150899957), (-23.06324303119446, -164.26810180330247), (-39.244944563419544, 33.17595496677325), (-76.49077452846423, -141.5365891870332), (19.9061778331165, -118.8693097085364), (16.312857655326766, -59.324663088852574), (19.572672240537273, -126.66169244912469), (52.941812817396766, 95.71148797049904), (57.386615449516995, 179.53380997918583), (83.7757212044823, -18.21272080360569), (64.01734929033961, 7.258559671423114), (-2.9088880429939508, 88.57774437102063), (-74.13193115166605, -21.039180804486193), (2.1311299441171343, -9.758401190927174), (36.85227734901201, -178.98074620006884), (-34.581084824270114, -6.34703875267968), (55.03924791596171, -78.58667275499731), (-69.63554330983703, 146.68761680248917), (-40.666098569390634, 177.32796626451938), (19.064566809852167, -138.99186330546263), (1.6122861481209867, 37.83389484954421), (45.32720286863389, -30.28364539369028), (-53.39650125373585, -168.09982338954924), (22.583618794820367, 78.9132859080903), (-61.07520927186283, -45.50011104482806), (53.93838614106204, -173.90610138008648), (-20.097671837491248, -160.24406864519375), (-61.24164513827786, -84.03210676265327), (-2.3791309236622027, -161.90471923085323), (88.12784943943095, 71.52657547213835), (-67.63671819370586, 174.09283292604982),  ...

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
     
    # Add 1 to the record count.
    record_count += 1
    
  # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
         
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | vanimo
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | sumbawanga
# Processing Record 8 of Set 1 | rocha
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | nioro
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | namibe
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | ixtapa
# Processing Record 24 of Set 1 | omidiyeh
# Processing Record 25 of Set 1 | springdale
# Processing Record 26 of Set 1 | gat
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | northam
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | angoram
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | half moon bay
# Processing Record 38 of Set 1 | maryanovka
# City not found. Skipping...
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | mudanya
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | iwaki
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | camana
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | zhicheng
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | mpanda
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | port-gentil
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | knysna
# Processing Record 12 of Set 2 | nome
# Processing Record 13 of Set 2 | novotroitskaya
# Processing Record 14 of Set 2 | kavieng
# Processing Record 15 of Set 2 | egvekinot
# Processing Record 16 of Set 2 | kamenka
# Processing Record 17 of Set 2 | sikonge
# Processing Record 18 of Set 2 | kushima
# Processing Record 19 of Set 2 | chunskiy
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | nanortalik
# Processing Record 24 of Set 2 | russell
# Processing Record 25 of Set 2 | szentgotthard
# Processing Record 26 of Set 2 | opuwo
# Processing Record 27 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | chernyshevskiy
# Processing Record 31 of Set 2 | sao filipe
# Processing Record 32 of Set 2 | marsabit
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | litovko
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | sao joao da barra
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | huazolotitlan
# City not found. Skipping...
# Processing Record 42 of Set 2 | flin flon
# Processing Record 43 of Set 2 | taoudenni
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | bredasdorp
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | djang
# City not found. Skipping...
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | rawson
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | tromso
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | winchester
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | marovoay
# Processing Record 9 of Set 3 | portsmouth
# Processing Record 10 of Set 3 | palmer
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | le vauclin
# Processing Record 13 of Set 3 | carrefour
# Processing Record 14 of Set 3 | ishigaki
# Processing Record 15 of Set 3 | nowy targ
# Processing Record 16 of Set 3 | imbituba
# Processing Record 17 of Set 3 | zheleznodorozhnyy
# Processing Record 18 of Set 3 | mangan
# Processing Record 19 of Set 3 | lasa
# Processing Record 20 of Set 3 | hovd
# Processing Record 21 of Set 3 | kieta
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | eureka
# Processing Record 24 of Set 3 | oranjemund
# Processing Record 25 of Set 3 | piacabucu
# Processing Record 26 of Set 3 | sobolevo
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | comodoro rivadavia
# Processing Record 29 of Set 3 | auki
# Processing Record 30 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 3 | zhangye
# Processing Record 32 of Set 3 | lorengau
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 3 | tokonou
# Processing Record 36 of Set 3 | padang
# Processing Record 37 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 3 | teguise
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | chulman
# Processing Record 41 of Set 3 | avera
# Processing Record 42 of Set 3 | lalin
# Processing Record 43 of Set 3 | batticaloa
# Processing Record 44 of Set 3 | naze
# Processing Record 45 of Set 3 | bridgetown
# Processing Record 46 of Set 3 | evensk
# Processing Record 47 of Set 3 | paranaiba
# Processing Record 48 of Set 3 | portland
# Processing Record 49 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 50 of Set 3 | coquimbo
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | kamina
# Processing Record 4 of Set 4 | altay
# Processing Record 5 of Set 4 | fortuna
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 4 | tlacote el bajo
# Processing Record 9 of Set 4 | zhigansk
# Processing Record 10 of Set 4 | praya
# Processing Record 11 of Set 4 | the pas
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | kushiro
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | manavalakurichi
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | marawi
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | tole
# Processing Record 20 of Set 4 | strelka
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | teguldet
# Processing Record 24 of Set 4 | plouzane
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | togul
# Processing Record 27 of Set 4 | miraflores
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | olinda
# Processing Record 30 of Set 4 | vieques
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | yenagoa
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | tecoanapa
# Processing Record 35 of Set 4 | srednekolymsk
# Processing Record 36 of Set 4 | turukhansk
# Processing Record 37 of Set 4 | ambilobe
# Processing Record 38 of Set 4 | erdenet
# Processing Record 39 of Set 4 | maumere
# Processing Record 40 of Set 4 | kununurra
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | lompoc
# Processing Record 43 of Set 4 | tawang
# Processing Record 44 of Set 4 | livingston
# Processing Record 45 of Set 4 | barcelona
# Processing Record 46 of Set 4 | cedar city
# Processing Record 47 of Set 4 | nova olimpia
# Processing Record 48 of Set 4 | vila velha
# Processing Record 49 of Set 4 | luzon
# Processing Record 50 of Set 4 | devonport
# Processing Record 1 of Set 5 | santa rosa
# Processing Record 2 of Set 5 | christchurch
# Processing Record 3 of Set 5 | cape town
# Processing Record 4 of Set 5 | soubre
# Processing Record 5 of Set 5 | guanica
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | puerto del rosario
# Processing Record 10 of Set 5 | muncar
# Processing Record 11 of Set 5 | duz
# City not found. Skipping...
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | torrington
# Processing Record 14 of Set 5 | bambanglipuro
# Processing Record 15 of Set 5 | bondoukou
# Processing Record 16 of Set 5 | lavrentiya
# Processing Record 17 of Set 5 | leshukonskoye
# Processing Record 18 of Set 5 | matai
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | tutoia
# Processing Record 21 of Set 5 | cadereyta
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 5 | hurghada
# Processing Record 24 of Set 5 | manokwari
# Processing Record 25 of Set 5 | molos
# Processing Record 26 of Set 5 | kaeo
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | kambove
# Processing Record 29 of Set 5 | yulara
# Processing Record 30 of Set 5 | chifeng
# Processing Record 31 of Set 5 | bundi
# Processing Record 32 of Set 5 | tiarei
# Processing Record 33 of Set 5 | basco
# Processing Record 34 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 5 | santiago
# Processing Record 36 of Set 5 | tarija
# Processing Record 37 of Set 5 | datong
# Processing Record 38 of Set 5 | provideniya
# Processing Record 39 of Set 5 | ahuimanu
# Processing Record 40 of Set 5 | moose factory
# Processing Record 41 of Set 5 | broome
# Processing Record 42 of Set 5 | te anau
# Processing Record 43 of Set 5 | kupang
# Processing Record 44 of Set 5 | superior
# Processing Record 45 of Set 5 | cheyenne
# Processing Record 46 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 5 | karratha
# Processing Record 48 of Set 5 | tautira
# Processing Record 49 of Set 5 | bronnoysund
# Processing Record 50 of Set 5 | leningradskiy
# Processing Record 1 of Set 6 | tessalit
# Processing Record 2 of Set 6 | le port
# Processing Record 3 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 6 | ullapool
# Processing Record 5 of Set 6 | atambua
# Processing Record 6 of Set 6 | isla aguada
# Processing Record 7 of Set 6 | powassan
# Processing Record 8 of Set 6 | sambava
# Processing Record 9 of Set 6 | umm kaddadah
# Processing Record 10 of Set 6 | maniitsoq
# Processing Record 11 of Set 6 | monrovia
# Processing Record 12 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 6 | kurgan
# Processing Record 14 of Set 6 | asyut
# Processing Record 15 of Set 6 | price
# Processing Record 16 of Set 6 | fengzhen
# Processing Record 17 of Set 6 | college
# Processing Record 18 of Set 6 | libreville
# Processing Record 19 of Set 6 | oistins
# Processing Record 20 of Set 6 | calvinia
# Processing Record 21 of Set 6 | berbera
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 6 | vao
# Processing Record 25 of Set 6 | mahonda
# Processing Record 26 of Set 6 | pontianak
# Processing Record 27 of Set 6 | lakes entrance
# Processing Record 28 of Set 6 | jackson
# Processing Record 29 of Set 6 | wewak
# Processing Record 30 of Set 6 | abnub
# Processing Record 31 of Set 6 | soyo
# Processing Record 32 of Set 6 | yuanping
# Processing Record 33 of Set 6 | okara
# Processing Record 34 of Set 6 | almeirim
# Processing Record 35 of Set 6 | kamaishi
# Processing Record 36 of Set 6 | hasaki
# Processing Record 37 of Set 6 | byron bay
# Processing Record 38 of Set 6 | mayna
# Processing Record 39 of Set 6 | udachnyy
# Processing Record 40 of Set 6 | kawalu
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | rosarito
# Processing Record 44 of Set 6 | ponta delgada
# Processing Record 45 of Set 6 | sept-iles
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | kathu
# Processing Record 48 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 49 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 50 of Set 6 | nouadhibou
# Processing Record 1 of Set 7 | totness
# Processing Record 2 of Set 7 | rabo de peixe
# Processing Record 3 of Set 7 | salalah
# Processing Record 4 of Set 7 | sur
# Processing Record 5 of Set 7 | grand baie
# Processing Record 6 of Set 7 | ichinohe
# Processing Record 7 of Set 7 | ossora
# Processing Record 8 of Set 7 | kharan
# Processing Record 9 of Set 7 | kyabe
# Processing Record 10 of Set 7 | tamale
# Processing Record 11 of Set 7 | deniliquin
# Processing Record 12 of Set 7 | garcia hernandez
# Processing Record 13 of Set 7 | peleduy
# Processing Record 14 of Set 7 | gariaband
# Processing Record 15 of Set 7 | lamu
# Processing Record 16 of Set 7 | lukiv
# Processing Record 17 of Set 7 | muyezerskiy
# Processing Record 18 of Set 7 | mwene-ditu
# Processing Record 19 of Set 7 | bengkulu
# Processing Record 20 of Set 7 | okoneshnikovo
# Processing Record 21 of Set 7 | tarancon
# Processing Record 22 of Set 7 | bereda
# Processing Record 23 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | wahlstedt
# Processing Record 26 of Set 7 | tezu
# Processing Record 27 of Set 7 | port hedland
# Processing Record 28 of Set 7 | port shepstone
# Processing Record 29 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 7 | havelock
# Processing Record 31 of Set 7 | ostrovnoy
# Processing Record 32 of Set 7 | isangel
# Processing Record 33 of Set 7 | jalu
# Processing Record 34 of Set 7 | beloha
# Processing Record 35 of Set 7 | grajau
# Processing Record 36 of Set 7 | jaunpur
# Processing Record 37 of Set 7 | dubbo
# Processing Record 38 of Set 7 | buta
# Processing Record 39 of Set 7 | cururupu
# Processing Record 40 of Set 7 | inhambane
# Processing Record 41 of Set 7 | vardo
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | abu dhabi
# Processing Record 45 of Set 7 | harper
# Processing Record 46 of Set 7 | la ronge
# Processing Record 47 of Set 7 | flinders
# Processing Record 48 of Set 7 | jiexiu
# Processing Record 49 of Set 7 | severo-yeniseyskiy
# Processing Record 50 of Set 7 | jinchang
# Processing Record 1 of Set 8 | stykkisholmur
# Processing Record 2 of Set 8 | koslan
# Processing Record 3 of Set 8 | capelinha
# Processing Record 4 of Set 8 | adre
# Processing Record 5 of Set 8 | sassandra
# Processing Record 6 of Set 8 | sabang
# Processing Record 7 of Set 8 | morogoro
# Processing Record 8 of Set 8 | chapais
# Processing Record 9 of Set 8 | xining
# Processing Record 10 of Set 8 | gushikawa
# Processing Record 11 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 8 | saint-augustin
# Processing Record 13 of Set 8 | ketchikan
# Processing Record 14 of Set 8 | westport
# Processing Record 15 of Set 8 | victoria
# Processing Record 16 of Set 8 | asau
# Processing Record 17 of Set 8 | kayerkan
# Processing Record 18 of Set 8 | quelimane
# Processing Record 19 of Set 8 | impfondo
# Processing Record 20 of Set 8 | cabedelo
# Processing Record 21 of Set 8 | tommot
# Processing Record 22 of Set 8 | lucapa
# Processing Record 23 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 8 | ambanja
# Processing Record 25 of Set 8 | coihaique
# Processing Record 26 of Set 8 | geraldton
# Processing Record 27 of Set 8 | alice springs
# Processing Record 28 of Set 8 | emerald
# Processing Record 29 of Set 8 | suifenhe
# Processing Record 30 of Set 8 | kailaras
# Processing Record 31 of Set 8 | torbay
# Processing Record 32 of Set 8 | katsuura
# Processing Record 33 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 8 | basoko
# Processing Record 35 of Set 8 | luderitz
# Processing Record 36 of Set 8 | agadez
# Processing Record 37 of Set 8 | san francisco menendez
# Processing Record 38 of Set 8 | anadyr
# Processing Record 39 of Set 8 | lata
# Processing Record 40 of Set 8 | tripoli
# Processing Record 41 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 42 of Set 8 | riberalta
# Processing Record 43 of Set 8 | abu samrah
# Processing Record 44 of Set 8 | launceston
# Processing Record 45 of Set 8 | boca do acre
# Processing Record 46 of Set 8 | grafenau
# Processing Record 47 of Set 8 | narsaq
# Processing Record 48 of Set 8 | ilebo
# Processing Record 49 of Set 8 | ahipara
# Processing Record 50 of Set 8 | iquitos
# Processing Record 1 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 9 | kungurtug
# Processing Record 3 of Set 9 | thinadhoo
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | paducah
# Processing Record 6 of Set 9 | rio gallegos
# Processing Record 7 of Set 9 | tokur
# Processing Record 8 of Set 9 | canto do buriti
# Processing Record 9 of Set 9 | huarmey
# Processing Record 10 of Set 9 | kruisfontein
# Processing Record 11 of Set 9 | banjar
# Processing Record 12 of Set 9 | sheopur
# Processing Record 13 of Set 9 | rio grande
# Processing Record 14 of Set 9 | sorong
# Processing Record 15 of Set 9 | goundam
# Processing Record 16 of Set 9 | ambon
# Processing Record 17 of Set 9 | namuac
# Processing Record 18 of Set 9 | dumas
# Processing Record 19 of Set 9 | sitka
# Processing Record 20 of Set 9 | mezen
# Processing Record 21 of Set 9 | raul soares
# Processing Record 22 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 9 | ilulissat
# Processing Record 24 of Set 9 | parana
# Processing Record 25 of Set 9 | luena
# Processing Record 26 of Set 9 | morehead
# Processing Record 27 of Set 9 | sri aman
# Processing Record 28 of Set 9 | urumqi
# Processing Record 29 of Set 9 | vondrozo
# Processing Record 30 of Set 9 | colesberg
# Processing Record 31 of Set 9 | clovis
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | vrangel
# Processing Record 34 of Set 9 | mehamn
# Processing Record 35 of Set 9 | fort nelson
# Processing Record 36 of Set 9 | roald
# Processing Record 37 of Set 9 | talnakh
# Processing Record 38 of Set 9 | kyritz
# Processing Record 39 of Set 9 | sidrolandia
# Processing Record 40 of Set 9 | santo antonio do ica
# Processing Record 41 of Set 9 | caraquet
# Processing Record 42 of Set 9 | arang
# Processing Record 43 of Set 9 | allen
# Processing Record 44 of Set 9 | wajima
# Processing Record 45 of Set 9 | vila franca do campo
# Processing Record 46 of Set 9 | charters towers
# Processing Record 47 of Set 9 | lerwick
# Processing Record 48 of Set 9 | bubaque
# Processing Record 49 of Set 9 | menomonie
# Processing Record 50 of Set 9 | salisbury
# Processing Record 1 of Set 10 | mecca
# Processing Record 2 of Set 10 | manacapuru
# Processing Record 3 of Set 10 | the valley
# Processing Record 4 of Set 10 | puerto boyaca
# Processing Record 5 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 6 of Set 10 | shache
# Processing Record 7 of Set 10 | raga
# Processing Record 8 of Set 10 | truth or consequences
# Processing Record 9 of Set 10 | kavaratti
# Processing Record 10 of Set 10 | balkhash
# Processing Record 11 of Set 10 | magadan
# Processing Record 12 of Set 10 | kholodnyy
# Processing Record 13 of Set 10 | sao paulo de olivenca
# Processing Record 14 of Set 10 | kahului
# Processing Record 15 of Set 10 | yantal
# Processing Record 16 of Set 10 | bud
# Processing Record 17 of Set 10 | zambezi
# Processing Record 18 of Set 10 | deputatskiy
# Processing Record 19 of Set 10 | ereymentau
# Processing Record 20 of Set 10 | port blair
# Processing Record 21 of Set 10 | mersing
# Processing Record 22 of Set 10 | morwell
# Processing Record 23 of Set 10 | ruwi
# Processing Record 24 of Set 10 | poya
# Processing Record 25 of Set 10 | elkhart
# Processing Record 26 of Set 10 | pangoa
# Processing Record 27 of Set 10 | sofiyivka
# Processing Record 28 of Set 10 | seddon
# Processing Record 29 of Set 10 | vostok
# Processing Record 30 of Set 10 | pachino
# Processing Record 31 of Set 10 | darnah
# Processing Record 32 of Set 10 | marsa matruh
# Processing Record 33 of Set 10 | broken hill
# Processing Record 34 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 10 | beringovskiy
# Processing Record 36 of Set 10 | nelson bay
# Processing Record 37 of Set 10 | honiara
# Processing Record 38 of Set 10 | shirokiy
# Processing Record 39 of Set 10 | pietarsaari
# Processing Record 40 of Set 10 | kokstad
# Processing Record 41 of Set 10 | lagoa
# Processing Record 42 of Set 10 | voh
# Processing Record 43 of Set 10 | keuruu
# Processing Record 44 of Set 10 | vila
# Processing Record 45 of Set 10 | carlyle
# Processing Record 46 of Set 10 | mitchell
# Processing Record 47 of Set 10 | oksfjord
# Processing Record 48 of Set 10 | sao jose da coroa grande
# Processing Record 49 of Set 10 | tura
# Processing Record 50 of Set 10 | gilgit
# Processing Record 1 of Set 11 | katangli
# Processing Record 2 of Set 11 | cayenne
# Processing Record 3 of Set 11 | jieshi
# Processing Record 4 of Set 11 | orlik
# Processing Record 5 of Set 11 | sayville
# Processing Record 6 of Set 11 | jambi
# Processing Record 7 of Set 11 | kamloops
# Processing Record 8 of Set 11 | mbanza-ngungu
# Processing Record 9 of Set 11 | nemuro
# Processing Record 10 of Set 11 | kologriv
# Processing Record 11 of Set 11 | dwarka
# Processing Record 12 of Set 11 | barabai
# Processing Record 13 of Set 11 | lodwar
# Processing Record 14 of Set 11 | mackay
# Processing Record 15 of Set 11 | vanavara
# Processing Record 16 of Set 11 | meulaboh
# Processing Record 17 of Set 11 | sinnamary
# Processing Record 18 of Set 11 | cibitoke
# Processing Record 19 of Set 11 | kurilsk
# Processing Record 20 of Set 11 | alot
# Processing Record 21 of Set 11 | ballina
# Processing Record 22 of Set 11 | coahuayana
# Processing Record 23 of Set 11 | bensonville
# Processing Record 24 of Set 11 | teya
# Processing Record 25 of Set 11 | sabzevar
# Processing Record 26 of Set 11 | vangaindrano
# Processing Record 27 of Set 11 | saint-medard-en-jalles
# Processing Record 28 of Set 11 | anloga
# Processing Record 29 of Set 11 | tuatapere
# Processing Record 30 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 11 | codrington
# Processing Record 32 of Set 11 | margate
# Processing Record 33 of Set 11 | esperance
# Processing Record 34 of Set 11 | ko samui
# Processing Record 35 of Set 11 | ngunguru
# Processing Record 36 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 11 | namatanai
# Processing Record 38 of Set 11 | sharan
# Processing Record 39 of Set 11 | bhadrapur
# Processing Record 40 of Set 11 | vallenar
# Processing Record 41 of Set 11 | san cristobal
# Processing Record 42 of Set 11 | obo
# Processing Record 43 of Set 11 | tomatlan
# Processing Record 44 of Set 11 | atherton
# Processing Record 45 of Set 11 | wasilla
# Processing Record 46 of Set 11 | dyersburg
# Processing Record 47 of Set 11 | sibolga
# Processing Record 48 of Set 11 | tarrafal
# Processing Record 49 of Set 11 | samarai
# Processing Record 50 of Set 11 | saint-louis
# Processing Record 1 of Set 12 | faya
# Processing Record 2 of Set 12 | iberia
# Processing Record 3 of Set 12 | tanabe
# Processing Record 4 of Set 12 | pangody
# Processing Record 5 of Set 12 | topchikha
# Processing Record 6 of Set 12 | oni
# Processing Record 7 of Set 12 | caceres
# Processing Record 8 of Set 12 | kigali
# Processing Record 9 of Set 12 | antalaha
# Processing Record 10 of Set 12 | san isidro
# Processing Record 11 of Set 12 | bollnas
# Processing Record 12 of Set 12 | san juan
# Processing Record 13 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 12 | mandalgovi
# Processing Record 15 of Set 12 | anchorage
# Processing Record 16 of Set 12 | gornopravdinsk
# Processing Record 17 of Set 12 | khabary
# Processing Record 18 of Set 12 | havre-saint-pierre
# Processing Record 19 of Set 12 | pacific grove
# Processing Record 20 of Set 12 | boone
# Processing Record 21 of Set 12 | kyra
# Processing Record 22 of Set 12 | gardiner
# Processing Record 23 of Set 12 | comendador
# Processing Record 24 of Set 12 | hailar
# Processing Record 25 of Set 12 | okha
# Processing Record 26 of Set 12 | hami
# Processing Record 27 of Set 12 | williston
# Processing Record 28 of Set 12 | kudahuvadhoo
# Processing Record 29 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 12 | yar-sale
# Processing Record 31 of Set 12 | xinpu
# Processing Record 32 of Set 12 | sembe
# Processing Record 33 of Set 12 | ponta do sol
# Processing Record 34 of Set 12 | bundaberg
# Processing Record 35 of Set 12 | naustdal
# Processing Record 36 of Set 12 | vestmannaeyjar
# Processing Record 37 of Set 12 | orsk
# Processing Record 38 of Set 12 | srandakan
# Processing Record 39 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 40 of Set 12 | verkhnyaya inta
# Processing Record 41 of Set 12 | along
# Processing Record 42 of Set 12 | macomer
# Processing Record 43 of Set 12 | birao
# Processing Record 44 of Set 12 | ganganagar
# Processing Record 45 of Set 12 | angouleme
# Processing Record 46 of Set 12 | kloulklubed
# Processing Record 47 of Set 12 | lensk
# Processing Record 48 of Set 12 | albion
# Processing Record 49 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 12 | senanga
# Processing Record 1 of Set 13 | voskresensk
# Processing Record 2 of Set 13 | pangnirtung
# Processing Record 3 of Set 13 | hambantota
# Processing Record 4 of Set 13 | whitehorse
# Processing Record 5 of Set 13 | pare
# Processing Record 6 of Set 13 | loandjili
# Processing Record 7 of Set 13 | qaqortoq
# Processing Record 8 of Set 13 | cherkasskoye
# Processing Record 9 of Set 13 | mitsamiouli
# Processing Record 10 of Set 13 | san felipe
# Processing Record 11 of Set 13 | touros
# Processing Record 12 of Set 13 | tulum
# Processing Record 13 of Set 13 | yelyzavethradka
# Processing Record 14 of Set 13 | yingshang
# City not found. Skipping...
# Processing Record 15 of Set 13 | nanakuli
# Processing Record 16 of Set 13 | tawzar
# City not found. Skipping...
# Processing Record 17 of Set 13 | zhezkazgan
# Processing Record 18 of Set 13 | praia da vitoria
# Processing Record 19 of Set 13 | walvis bay
# Processing Record 20 of Set 13 | sarangani
# Processing Record 21 of Set 13 | mooi river
# City not found. Skipping...
# Processing Record 22 of Set 13 | aswan
# Processing Record 23 of Set 13 | dingle
# Processing Record 24 of Set 13 | talcahuano
# Processing Record 25 of Set 13 | san estanislao
# Processing Record 26 of Set 13 | barber
# Processing Record 27 of Set 13 | kells
# Processing Record 28 of Set 13 | sisimiut
# Processing Record 29 of Set 13 | strezhevoy
# Processing Record 30 of Set 13 | clyde river
# Processing Record 31 of Set 13 | tres arroyos
# Processing Record 32 of Set 13 | grand gaube
# Processing Record 33 of Set 13 | vokhtoga
# Processing Record 34 of Set 13 | nishihara
# Processing Record 35 of Set 13 | grindavik
# Processing Record 36 of Set 13 | bilma
# Processing Record 37 of Set 13 | fairbanks
# Processing Record 38 of Set 13 | mokhsogollokh
# Processing Record 39 of Set 13 | sangar
# Processing Record 40 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 41 of Set 13 | richards bay
# Processing Record 42 of Set 13 | imeni stepana razina
# Processing Record 43 of Set 13 | vagur
# Processing Record 44 of Set 13 | calbuco
# Processing Record 45 of Set 13 | ayolas
# Processing Record 46 of Set 13 | mikuni
# Processing Record 47 of Set 13 | akonolinga
# Processing Record 48 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 13 | koumac
# Processing Record 50 of Set 13 | maceio
# Processing Record 1 of Set 14 | ciudad bolivar
# Processing Record 2 of Set 14 | tahoua
# Processing Record 3 of Set 14 | chumikan
# Processing Record 4 of Set 14 | bruchsal
# Processing Record 5 of Set 14 | pangkalanbuun
# Processing Record 6 of Set 14 | bandarbeyla
# Processing Record 7 of Set 14 | marystown
# Processing Record 8 of Set 14 | acarau
# Processing Record 9 of Set 14 | dunedin
# Processing Record 10 of Set 14 | porto torres
# Processing Record 11 of Set 14 | komsomolskiy
# Processing Record 12 of Set 14 | jiangkou
# Processing Record 13 of Set 14 | morondava
# Processing Record 14 of Set 14 | ye
# City not found. Skipping...
# Processing Record 15 of Set 14 | hit
# Processing Record 16 of Set 14 | puerto baquerizo moreno
# Processing Record 17 of Set 14 | jiayuguan
# Processing Record 18 of Set 14 | carballo
# Processing Record 19 of Set 14 | porto novo
# Processing Record 20 of Set 14 | lokachi
# Processing Record 21 of Set 14 | conceicao do mato dentro
# Processing Record 22 of Set 14 | corpus christi
# Processing Record 23 of Set 14 | guadalupe victoria
# Processing Record 24 of Set 14 | porangatu
# Processing Record 25 of Set 14 | marathon
# Processing Record 26 of Set 14 | lingao
# Processing Record 27 of Set 14 | nisia floresta
# Processing Record 28 of Set 14 | barrhead
# Processing Record 29 of Set 14 | yandyki
# Processing Record 30 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 14 | baillif
# Processing Record 32 of Set 14 | hoogeveen
# Processing Record 33 of Set 14 | bah
# Processing Record 34 of Set 14 | palana
# Processing Record 35 of Set 14 | chicama
# Processing Record 36 of Set 14 | axim
# Processing Record 37 of Set 14 | henties bay
# Processing Record 38 of Set 14 | chadan
# Processing Record 39 of Set 14 | vulcan
# Processing Record 40 of Set 14 | zhanaozen
# Processing Record 41 of Set 14 | gualeguaychu
# Processing Record 42 of Set 14 | talgar
# Processing Record 43 of Set 14 | gusau
# Processing Record 44 of Set 14 | oussouye
# Processing Record 45 of Set 14 | middletown
# Processing Record 46 of Set 14 | fukue
# Processing Record 47 of Set 14 | lipin bor
# Processing Record 48 of Set 14 | yamada
# Processing Record 49 of Set 14 | kerema
# Processing Record 50 of Set 14 | alto araguaia
# Processing Record 1 of Set 15 | thessalon
# Processing Record 2 of Set 15 | jacksonville beach
# Processing Record 3 of Set 15 | burica
# City not found. Skipping...
# Processing Record 4 of Set 15 | yarada
# Processing Record 5 of Set 15 | lahaina
# Processing Record 6 of Set 15 | gallup
# Processing Record 7 of Set 15 | dromolaxia
# Processing Record 8 of Set 15 | itarema
# Processing Record 9 of Set 15 | hualmay
# Processing Record 10 of Set 15 | burnie
# Processing Record 11 of Set 15 | profitis ilias
# Processing Record 12 of Set 15 | karaton
# Processing Record 13 of Set 15 | amahai
# Processing Record 14 of Set 15 | kukushtan
# Processing Record 15 of Set 15 | qui nhon
# Processing Record 16 of Set 15 | havre
# Processing Record 17 of Set 15 | carbonia
# Processing Record 18 of Set 15 | puerto escondido
# Processing Record 19 of Set 15 | nampula
# Processing Record 20 of Set 15 | calama
# Processing Record 21 of Set 15 | port-cartier
# Processing Record 22 of Set 15 | chadiza
# Processing Record 23 of Set 15 | yima
# Processing Record 24 of Set 15 | saint-joseph
# Processing Record 25 of Set 15 | mabaruma
# Processing Record 26 of Set 15 | dengzhou
# Processing Record 27 of Set 15 | prince rupert
# Processing Record 28 of Set 15 | baherden
# Processing Record 29 of Set 15 | acapulco
# Processing Record 30 of Set 15 | malappuram
# Processing Record 31 of Set 15 | sangin
# Processing Record 32 of Set 15 | mazagao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 732

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Rikitea      PF -23.1203 -134.9692     77.83        77         100
# 1      Atuona      PF  -9.8000 -139.0333     78.31        73          21
# 2      Vanimo      PG  -2.6741  141.3028     77.45        88         100
# 3       Pevek      RU  69.7008  170.3133     -3.44        95         100
# 4  Sumbawanga      TZ  -7.9667   31.6167     70.52        67          56
# 5       Rocha      UY -34.4833  -54.3333     83.34        34           5
# 6      Castro      BR -24.7911  -50.0119     69.17        64          95
# 7   Upernavik      GL  72.7868  -56.1549      6.06        95         100
# 8       Nioro      GM  13.3500  -15.7500     95.50         9           6
# 9    Khatanga      RU  71.9667  102.5000     -9.22        77          99
#
#    Wind Speed   Current Description
# 0       20.04            light rain
# 1       17.69            few clouds
# 2        7.18  heavy intensity rain
# 3        2.15       overcast clouds
# 4        4.63            light rain
# 5       15.21             clear sky
# 6        6.26       overcast clouds
# 7        4.32            light snow
# 8        5.99             clear sky
# 9       11.83       overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
